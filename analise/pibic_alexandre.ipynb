# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %forks = pd.read_excel("fork.xlsx")

# %%
# %matplotlib inline
forks['update_status'].value_counts().plot.bar()
# Out:
# <Axes: >
