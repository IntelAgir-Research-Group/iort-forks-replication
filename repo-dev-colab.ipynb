# %% [markdown]
# <a href="https://colab.research.google.com/github/IntelAgir-Research-Group/iort-forks-replication/blob/main/Forks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import time
import sqlite3
import csv
import math
from google.colab import drive

drive.mount('/content/drive')

def get_repo_data(url, developer):

    # Requisicao
    response = requests.get(url, headers=headers)

    # Verificar se a requisição foi bem sucedida
    if response.status_code == 200:
        # Converter a resposta JSON em um objeto Python
        repo_info = json.loads(response.content)

        # Obter informações sobre o repositório
        repo_name = repo_info['name']
        print("Repo name: ", repo_name)
        repo_description = repo_info['description']
        repo_commits_url = repo_info['commits_url'].split('{')[0]
        repo_watchers = repo_info['watchers_count']
        repo_forks = repo_info['forks']
        repo_is_fork = repo_info['fork']
        repo_created_at = repo_info['created_at']
        repo_updated_at = repo_info['updated_at']

        # Criar uma tabela para armazenar as informações do repositório
        c.execute('''CREATE TABLE IF NOT EXISTS repos
                        (name TEXT, description TEXT, developer TEXT, commits_url TEXT, watchers INTEGER, forks INTEGER, is_fork TEXT, created_at TEXT, updated_at TEXT)''')

        # Inserir as informações do repositório no banco de dados
        c.execute("INSERT INTO repos VALUES (?, ?, ?, ?, ?, ?, ?, ?,?)", (repo_name, repo_description, developer, repo_commits_url, repo_watchers, repo_forks, repo_is_fork, repo_created_at,repo_updated_at))

        # Confirmar a transação e fechar a conexão
        conn.commit()

    else:
        # Exibir uma mensagem de erro se a requisição falhar
        print(f'Não foi possível buscar informações do usuário/repositório {username}/{repository}')
    # Pausar por 40 segundos antes de fazer a próxima requisição
    time.sleep(2)

def get_repositories(developer, page):
    url = f"https://api.github.com/users/{developer}/repos?page={page}"
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        repositories = response.json()
        for repo in repositories:
            repository = repo["name"]
            print("Getting data: ", repository)
            url = f'https://api.github.com/repos/{developer}/{repository}'
            get_repo_data(url, developer)
    else:
        print(f"Error: {response.status_code}")

with open('config.json') as config_file:
    config = json.load(config_file)
    token = config['token']
    # Adicionar o token de autenticação no cabeçalho da requisição
    headers = {'Authorization': f'Token {token}'}

# Criar uma conexão com o banco de dados SQL
conn = sqlite3.connect('/content/drive/MyDrive/Compartilhados/Research_Dev/Colab/Forks/dados/git.db')
c = conn.cursor()

with open('/content/drive/MyDrive/Compartilhados/Research_Dev/Colab/Forks/extracao/dev_qtde_repos.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)

    for row in reader:
        developer = row['username']
        qtde_repos = row['public_repos']
        pages = math.ceil(int(qtde_repos) / 30)
        print(developer," - pages: ", pages)
        for i in range(pages):
            get_repositories(developer, str(i))

# Fecha conexao com o banco
conn.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# alangchild  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  RCESN_spatio_temporal
# Repo name:  RCESN_spatio_temporal
# alfredv23  - pages:  1
# Getting data:  awesome-deep-learning
# Repo name:  awesome-deep-learning
# Getting data:  jetbot
# Repo name:  jetbot
# Chen-Youhui  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  python_nano
# Repo name:  python_nano
# davod0401  - pages:  1
# Getting data:  Janky-Bot
# Repo name:  Janky-Bot
# Getting data:  jetbot
# Repo name:  jetbot
# desvelado  - pages:  1
# Getting data:  Hello-world
# Repo name:  Hello-world
# Getting data:  jetbot
# Repo name:  jetbot
# dhjmackay  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  tensorflow
# Repo name:  tensorflow
# DPoPovski  - pages:  1
# Getting data:  DPoPovski
# Repo name:  DPoPovski
# Getting data:  jetbot
# Repo name:  jetbot
# ejunear  - pages:  1
# Getting data:  board
# Repo name:  board
# Getting data:  jetbot
# Repo name:  jetbot
# fernandozet  - pages:  1
# Getting data:  fernandozet.github.io
# Repo name:  fernandozet.github.io
# Getting data:  jetbot
# Repo name:  jetbot
# fvine  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  test
# Repo name:  test
# Gary0417  - pages:  1
# Getting data:  bangalore_house_price_prediction
# Repo name:  bangalore_house_price_prediction
# Getting data:  Gary0417
# Repo name:  Gary0417
# Getting data:  movie_recommendation_system
# Repo name:  movie_recommendation_system
# Getting data:  naive_bayes_spam_filter
# Repo name:  naive_bayes_spam_filter
# Getting data:  quora_insincere_questions_classification
# Repo name:  quora_insincere_questions_classification
# Getting data:  tomato_disease_classification
# Repo name:  tomato_disease_classification
# Getting data:  Zi_Xun_Portfolio
# Repo name:  Zi_Xun_Portfolio
# Gewoo1996  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  jetbot-1
# Repo name:  jetbot-1
# githubforever  - pages:  1
# Getting data:  bootstrap
# Repo name:  bootstrap
# Getting data:  jetbot
# Repo name:  jetbot
# hello-carry  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  LibraryManageSystem
# Repo name:  LibraryManageSystem
# hitmeok  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  roam-extension-color-highlighter
# Repo name:  roam-extension-color-highlighter
# hlloydt2  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  jetson-inference
# Repo name:  jetson-inference
# JoshSYoon  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  jetbot_mini
# Repo name:  jetbot_mini
# jtsc296  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  roadmap
# Repo name:  roadmap
# Khwan7662  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  Khwan7662
# Repo name:  Khwan7662
# lilacbeauty  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  yolov5
# Repo name:  yolov5
# luaw2006  - pages:  1
# Getting data:  apf
# Repo name:  apf
# Getting data:  jetbot
# Repo name:  jetbot
# manfermu86  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  manfermu86
# Repo name:  manfermu86
# mksbala  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  learnopencv
# Repo name:  learnopencv
# NCH-Dragonbolt  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  WebsiteDebug
# Repo name:  WebsiteDebug
# nlona  - pages:  1
# Getting data:  disco4g
# Repo name:  disco4g
# Getting data:  jetbot
# Repo name:  jetbot
# ogis-yamagishi  - pages:  1
# Getting data:  argocd-example-apps
# Repo name:  argocd-example-apps
# Getting data:  jetbot
# Repo name:  jetbot
# psnurhalim  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  jetracer
# Repo name:  jetracer
# Silicon-Box  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  minecraft-hacking
# Repo name:  minecraft-hacking
# specialwarheads  - pages:  1
# Getting data:  edgetpu-on-pi
# Repo name:  edgetpu-on-pi
# Getting data:  jetbot
# Repo name:  jetbot
# steffenteichmann  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  shop-repo
# Repo name:  shop-repo
# sxy641  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  sxy641.github.io
# Repo name:  sxy641.github.io
# thisisfranny  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  models
# Repo name:  models
# tjp1940  - pages:  1
# Getting data:  github-slideshow
# Repo name:  github-slideshow
# Getting data:  jetbot
# Repo name:  jetbot
# VickyLeeLove  - pages:  1
# Getting data:  helloworld
# Repo name:  helloworld
# Getting data:  jetbot
# Repo name:  jetbot
# UnitoX  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  trt_yolov4-tiny
# Repo name:  trt_yolov4-tiny
# WilliamXXie  - pages:  1
# Getting data:  hello-world
# Repo name:  hello-world
# Getting data:  jetbot
# Repo name:  jetbot
# yunhuakeji  - pages:  1
# Getting data:  ardupilot
# Repo name:  ardupilot
# Getting data:  jetbot
# Repo name:  jetbot
# zhangk19  - pages:  1
# Getting data:  jetbot
# Repo name:  jetbot
# Getting data:  tensorflow
# Repo name:  tensorflow
# zihui0325  - pages:  1
# Getting data:
